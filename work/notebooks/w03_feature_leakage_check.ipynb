# %% [markdown]
# # ML-05 — Feature Vector and Leakage/Privacy Check
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_feature_leakage_check.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# **Status: not taken as a separate assignment.** The ML-05 card was retired on 2026-07-13 and its core — the feature vector, the availability check and the leakage hunt — moved into **ML-04**. That work is done and lives in `w03_data_contract.ipynb` (sections 2, 3 and 3c: the four-bucket field table, the three verification queries, and the deliberate one-column leak with the honest score beside it), and it is re-run on the final feature set in `w06_validation_audit.ipynb` section 3 and again in `capstone.ipynb` section 4.
#
# This skeleton is left in place unfilled so the assignment index stays complete. Nothing below it is my work.

# %%
print("ML-05 was retired 2026-07-13; its core lives in ML-04.")
print("  feature vector + buckets + leakage hunt : w03_data_contract.ipynb, sections 2, 3, 3c")
print("  re-run on the shipped feature set       : w06_validation_audit.ipynb, section 3")
print("  re-run on the sealed release            : capstone.ipynb, section 4")
print()
print("this skeleton is intentionally unfilled.")
# Out:
# ML-05 was retired 2026-07-13; its core lives in ML-04.
#   feature vector + buckets + leakage hunt : w03_data_contract.ipynb, sections 2, 3, 3c
#   re-run on the shipped feature set       : w06_validation_audit.ipynb, section 3
#   re-run on the sealed release            : capstone.ipynb, section 4
#
# this skeleton is intentionally unfilled.

# %% [markdown]
# ## 1. Build the feature vector
#
# *Code that actually builds it — engineered features, categorical handling, fills.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Feature notes (meaning, missing, categorical, available-when?)
#
# *For each feature: what it means, how missing values are handled, and whether it exists BEFORE the moment you predict.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. The leakage hunt
#
# *Attack your own features: label-derived columns, future windows, product flags. Show the test.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. What I excluded and why
#
# *The list of fields you refused to use — with one line of why each.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
