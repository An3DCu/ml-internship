# %% [markdown]
# # ML-06 — Signal Audit: Do the Flags Hold?
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/An3DCu/ml-internship/blob/main/work/notebooks/w04_signal_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# **Status: not taken as a separate assignment.** The ML-06 card was retired on 2026-07-13 and its core — distributions, three signal tests with verdicts, and the flag-linked test — moved into **ML-07**. That work is done and lives in `w04_baseline_score.ipynb` section 1: staleness behind the refresh flags (verdict FALSE), CTR-for-position behind the CTR-fix flag (MIXED), and the within-month slide (CONFIRMED), each with a bucket table and an `n` beside every rate.
#
# This skeleton is left in place unfilled so the assignment index stays complete. Nothing below it is my work.

# %%
print("ML-06 was retired 2026-07-13; its core lives in ML-07.")
print("  distributions + 3 signal tests with verdicts : w04_baseline_score.ipynb, section 1")
print("    1a staleness / refresh flags   -> FALSE")
print("    1b CTR for position / CTR-fix  -> MIXED")
print("    1c within-month slide (mine)   -> CONFIRMED")
print()
print("this skeleton is intentionally unfilled.")
# Out:
# ML-06 was retired 2026-07-13; its core lives in ML-07.
#   distributions + 3 signal tests with verdicts : w04_baseline_score.ipynb, section 1
#     1a staleness / refresh flags   -> FALSE
#     1b CTR for position / CTR-fix  -> MIXED
#     1c within-month slide (mine)   -> CONFIRMED
#
# this skeleton is intentionally unfilled.

# %% [markdown]
# ## 1. Distributions
#
# *Look before deciding: distributions of your key fields. Note the heavy tails.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Signal test #1 / #2 / #3 (verdict each)
#
# *Three safe signals, each with a mini-test and a verdict: CONFIRMED / OPPOSITE / MIXED / FALSE.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. The flag-linked test
#
# *Pick a signal one of FlyRank's real flags relies on. Does the data support the rule's assumption?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. What this means in practice
#
# *Two or three sentences: what a content team should take from this.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
